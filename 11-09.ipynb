# %%
import pandas

# %%
data = pandas.read_excel("./期中成績 - 匿名.xlsx" ,header=1)

# %%
data
# Out:
#     ID  期中成績        帳號          單位      班級   1   2   3   4   5   6   7   8  \
# 0    1    75  4a980018  財務金融系 (08)  四技財金三甲  10  10  10  10   5  10  10  10
# 1    2     0  4a980020  財務金融系 (08)  四技財金三丙   0   0   0   0   0   0   0   0
# 2    3    80  4a980022  財務金融系 (08)  四技財金三乙  10  10  10  10  10  10  10  10
# 3    4    90  4a980035  財務金融系 (08)  四技財金三甲  10  10  10  10   5  10  10  10
# 4    5    70  4a980041  財務金融系 (08)  四技財金三乙  10  10  10  10  10  10  10   0
# 5    6    60  4a980043  財務金融系 (08)  四技財金三甲  10  10  10  10   5   5   5   0
# 6    7     5  4a980047  財務金融系 (08)  四技財金三甲   5   0   0   0   0   0   0   0
# 7    8    75  4a980053  財務金融系 (08)  四技財金三甲  10  10  10  10   5  10  10  10
# 8    9    60  4a980071  財務金融系 (08)  四技財金三甲  10  10  10  10   5   5   5   5
# 9   10     0  4a980073  財務金融系 (08)  四技財金三丙   0   0   0   0   0   0   0   0
# 10  11    60  4a980077  財務金融系 (08)  四技財金三甲  10  10  10  10  10   5   5   0
# ...

# %%
data["期中成績"].mean()
# Out:
# 52.02127659574468

# %%
data["期中成績"].median()
# Out:
# 55.0

# %%
data.describe()
# Out:
#               ID        期中成績          1          2          3          4  \
# count  47.000000   47.000000  47.000000  47.000000  47.000000  47.000000
# mean   24.000000   52.021277   8.510638   8.191489   7.127660   6.914894
# std    13.711309   30.389851   3.444418   3.820075   4.513829   4.610148
# min     1.000000    0.000000   0.000000   0.000000   0.000000   0.000000
# 25%    12.500000   27.500000  10.000000  10.000000   0.000000   0.000000
# 50%    24.000000   55.000000  10.000000  10.000000  10.000000  10.000000
# 75%    35.500000   75.000000  10.000000  10.000000  10.000000  10.000000
# max    47.000000  100.000000  10.000000  10.000000  10.000000  10.000000
#
#                5          6          7          8          9         10
# count  47.000000  47.000000  47.000000  47.000000  47.000000  47.000000
# mean    4.893617   4.148936   4.255319   4.468085   2.127660   1.382979
# std     4.482983   4.338797   4.660043   4.804215   4.003352   3.075522
# ...

# %%
data["期中成績"].plot(kind="hist",figsize=[15,8])
# Out:
# <AxesSubplot:ylabel='Frequency'>

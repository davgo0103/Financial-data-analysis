# %%
import pandas

# %%
data = pandas.read_excel("./期中成績 - 匿名.xlsx")

# %%
data
# Out:
#    80D1A301 金融大數據分析_四技財金三甲等合開 - 學員名單 Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                 ID       期中成績         帳號          單位
# 1                                  1         75   4a980018  財務金融系 (08)
# 2                                  2          0   4a980020  財務金融系 (08)
# 3                                  3         80   4a980022  財務金融系 (08)
# 4                                  4         90   4a980035  財務金融系 (08)
# 5                                  5         70   4a980041  財務金融系 (08)
# 6                                  6         60   4a980043  財務金融系 (08)
# 7                                  7          5   4a980047  財務金融系 (08)
# 8                                  8         75   4a980053  財務金融系 (08)
# 9                                  9         60   4a980071  財務金融系 (08)
# 10                                10          0   4a980073  財務金融系 (08)
# 11                                11         60   4a980077  財務金融系 (08)
# ...
